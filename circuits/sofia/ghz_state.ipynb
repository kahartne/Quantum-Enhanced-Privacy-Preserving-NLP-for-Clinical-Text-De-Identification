# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator

#GHZ state - 3 qubit gate by gate
qc = QuantumCircuit(3)
qc.h(0)         #put qubit 0 into superposition
qc.cx(0, 1)     #entangle qubit 0 with qubit 1
qc.cx(0, 2)     #entangle qubit 0 with qubit 2
qc.measure_all()

sim = AerSimulator()
result = sim.run(qc, shots=1000).result()
print(result.get_counts())
# Out:
# {'000': 507, '111': 493}

# %%
from qiskit.quantum_info import Statevector

#same circuit no measurement so I can see the state itself
qc_ghz = QuantumCircuit(3)
qc_ghz.h(0)
qc_ghz.cx(0, 1)
qc_ghz.cx(0, 2)
print("GHZ state:", Statevector(qc_ghz))
# Out:
# GHZ state: Statevector([0.70710678+0.j, 0.        +0.j, 0.        +0.j,
#              0.        +0.j, 0.        +0.j, 0.        +0.j,
#              0.        +0.j, 0.70710678+0.j],
#             dims=(2, 2, 2))
